# %% [markdown]
# # Test Bot: Discord Webhook
#
# Sends a simple greeting message to a Discord channel via an incoming webhook.

# %%
import requests

WEBHOOK_URL = "https://discord.com/api/webhooks/1551769386371653743/4IifAuKdOWJWzzbzZtMxhhDdq5X62Y07GfiLyY0ru5BPjolyzlA4FaACRMUkp_5k8o4U"

payload = {"content": "hi this is Fiji bot"}

response = requests.post(WEBHOOK_URL, json=payload)
print("Status code:", response.status_code)
print("Response body:", response.text)
response.raise_for_status()
